# %%
# PANDAS DAY 2....

# %%
import pandas as pd

# %%
df = pd.read_csv('covid_toy - covid_toy.csv')
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df1 = pd.read_csv('placement - placement.csv')
df1
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df2 = pd.read_csv('tips - tips.csv')
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df3 = pd.read_csv('titanic - titanic.csv')
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df1.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df1.info()   #  data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df1.describe()   # statically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
top_left_corner_df1 = df1.iloc[:4 , :3]  #iloc[row_range , colum_range]
top_left_corner_df1
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df1.loc[1:3 , ['cgpa' , 'placed']]  #loc[row_range , colum_name]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
p = df1.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b= df.empty   # it return true if there are any missing datta in dataframe otherwise it will return false.
b
# Out:
# False

# %%
df1.isnull().sum()   # to check missing values
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df1.dropna()   # to remove missing row
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df1 = df1.sample()
df1
# Out:
#     cgpa  resume_score  placed
# 25  7.76          5.68       1

# %%
df5 = pd.read_csv('flipkart.csv')
df5
# Out:
#                                           VJA3rP href  \
# 0   https://www.flipkart.com/boldfit-clothing-blac...
# 1   https://www.flipkart.com/scoyco-k11-1-adjustab...
# 2   https://www.flipkart.com/steelbird-polyester-a...
# 3   https://www.flipkart.com/zaysoo-helmet-face-ma...
# 4   https://www.flipkart.com/subhusha-polyester-ny...
# 5   https://www.flipkart.com/trazo-cotton-arm-slee...
# 6   https://www.flipkart.com/steelbird-bike-riding...
# 7   https://www.flipkart.com/mohan-retail-nylon-ar...
# 8   https://www.flipkart.com/mohan-retail-cotton-a...
# 9   https://www.flipkart.com/mohan-retail-cotton-a...
# 10                                                NaN
# 11                                                NaN
#
#                                            DByuf4 src  \
# 0   https://rukminim2.flixcart.com/image/612/612/x...
# 1   https://rukminim2.flixcart.com/image/612/612/x...
# 2   https://rukminim2.flixcart.com/image/612/612/x...
# ...

# %%
import pandas as pd

# %%
df1 = pd.read_csv('placement - placement.csv')
df1
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df1.head()  # top 5 data
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df1.tail()    #bottom 5 data
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df1.sample()
# Out:
#     cgpa  resume_score  placed
# 26  6.27          6.47       0

# %%
df1.describe()   #statically view data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df1.info() # data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df1 = df1.iloc[:4 , :3]   # iloc[row_range , colum_range]
top_left_corner_df1
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df1.loc[1:3 , ['cgpa','placed']]   # loc [row_range, colum_name]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
p = df1.dtypes  # for data type
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df1.empty  # it return true if there is any missing dataframe otherwise return false.
b
# Out:
# False

# %%
df1.isnull().sum()  # to check the missing value
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df1 = df1.dropna()   # to remove missing row

# %%
i = df1.ndim  # number of axes(it is 2)
i
# Out:
# 2

# %%
t = df1.shape  # shape = (rows),n(colums)
t
# Out:
# (100, 3)

# %%
d = df1.size    # row count * colum count
d
# Out:
# 300

# %%
a = df1.values  #to get a numpy array for df1
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
 df1 = df1.copy()  # crating a copy of exesting dataframe , any changes done in copy will not affect the original data.

# %%
p = df1.sort_values(by = 'resume_score')
p   # to select a specific coloum and arrange in assending order.
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r = df1.sort_index()  # 
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# x=df1.astype(int)  # type conversion
df1['cgpa'] = df1['cgpa'].astype(int)  # to change the datatype of an data
df1
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
# to add the data
# t = df1.add(4\value)

df1['cgpa'] = df1['cgpa'].add(4)
df1
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
df1['cgpa'].add(10)
df1
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
s = df1.count()  # to check the frequency of colum
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df1.max()  # will give the maximum value of every colum
p
# Out:
# cgpa            13.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
q = df1.min()  # will return the minimum value of the data frame
q
# Out:
# cgpa            9.00
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
r = df1['cgpa'].mean()   # to get the average of the data
r
# Out:
# 10.47

# %%
s = df1['cgpa'].median()   # it also use to get the average
s
# Out:
# 10.0

# %%
s = df1.sum()
s
# Out:
# cgpa            1047.00
# resume_score     693.05
# placed            50.00
# dtype: float64

# %%
g = df1.filter(items = ['cgpa','placed'])
g   # filter out the selected data from the dataframe
df1[['cgpa','placed']]   # second way to do filter
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
s = df1.filter(items=[5,6],axis=0)
s
# Out:
#    cgpa  resume_score  placed
# 5    12          6.19       1
# 6     9          7.09       0

# %%
s = df1.to_dict()  # to save in dictionary form
s
# Out:
# {'cgpa': {0: 12,
#   1: 10,
#   2: 12,
#   3: 10,
#   4: 11,
#   5: 12,
#   6: 9,
#   7: 10,
#   8: 10,
#   9: 11,
#   10: 10,
#   11: 9,
#   12: 10,
#   13: 12,
#   14: 11,
#   15: 12,
#   16: 12,
#   17: 11,
#   18: 9,
#   19: 10,
#   20: 9,
#   21: 10,
#   22: 10,
#   23: 10,
#   24: 12,
#   25: 11,
#   26: 10,
#   27: 9,
#   28: 11,
#   29: 10,
#   30: 11,
#   31: 9,
#   32: 9,
#   33: 12,
#   34: 12,
#   35: 12,
#   36: 12,
#   37: 13,
#   38: 10,
#   39: 11,
#   40: 12,
#   41: 12,
#   42: 10,
#   43: 12,
#   44: 9,
#   45: 12,
#   46: 9,
#   47: 11,
#   48: 9,
#   49: 9,
#   50: 12,
#   51: 10,
#   52: 9,
#   53: 10,
#   54: 9,
#   55: 10,
#   56: 10,
#   57: 10,
#   58: 10,
#   59: 9,
#   60: 9,
#   61: 10,
#   62: 9,
#   63: 12,
#   64: 11,
#   65: 10,
#   66: 12,
#   67: 10,
#   68: 10,
#   69: 12,
#   70: 11,
#   71: 11,
#   72: 11,
#   73: 9,
#   74: 9,
#   75: 10,
#   76: 13,
#   77: 9,
#   78: 9,
#   79: 9,
#   80: 11,
#   81: 10,
#   82: 11,
#   83: 11,
#   84: 9,
# ...

# %%
q= df1.to_string()  # to save in string form
q
# Out:
# '    cgpa  resume_score  placed\n0     12          6.52       1\n1     10          5.17       0\n2     12          8.86       1\n3     10          7.27       1\n4     11          7.30       1\n5     12          6.19       1\n6      9          7.09       0\n7     10          6.29       0\n8     10          6.71       0\n9     11          7.12       1\n10    10          6.35       0\n11     9          6.54       0\n12    10          7.01       0\n13    12          5.09       1\n14    11          6.25       1\n15    12          5.93       1\n16    12          7.64       1\n17    11          8.71       1\n18     9          5.88       0\n19    10          8.11       1\n20     9          8.06       0\n21    10          7.64       0\n22    10          5.77       0\n23    10          7.13       0\n24    12          6.18       1\n25    11          5.68       1\n26    10          6.47       0\n27     9          6.15       0\n28    11          7.67       1\n29    10          7.30       0\n30   
# ...

# %%
e = df1.to_csv("path location")
e

# %%
idx = df1.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label = df1.columns[0]  # to get the colum label
label
# Out:
# 'cgpa'

# %%
p = df1.columns.tolist()   # list of column labels
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
q = df1.columns.values   # array tocolumn label
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p = df1.rename(columns={'cgpa':'updated_cgpa',
                        'resume_svore':'semester_marks'})
p   # how to rename a column
# Out:
#     updated_cgpa  resume_score  placed
# 0             12          6.52       1
# 1             10          5.17       0
# 2             12          8.86       1
# 3             10          7.27       1
# 4             11          7.30       1
# ..           ...           ...     ...
# 95            10          6.38       0
# 96            12          7.76       1
# 97            10          7.78       0
# 98            12          5.63       1
# 99            10          6.61       0
#
# [100 rows x 3 columns]

# %%
df1['Cgpa1'] = df1['cgpa'].astype(int)
df1   # creating a new column
# Out:
#     cgpa  resume_score  placed  Cgpa1
# 0     12          6.52       1     12
# 1     10          5.17       0     10
# 2     12          8.86       1     12
# 3     10          7.27       1     10
# 4     11          7.30       1     11
# ..   ...           ...     ...    ...
# 95    10          6.38       0     10
# 96    12          7.76       1     12
# 97    10          7.78       0     10
# 98    12          5.63       1     12
# 99    10          6.61       0     10
#
# [100 rows x 4 columns]

# %%
a= df1.drop(columns=['cgpa','placed'])
a
# Out:
#     resume_score  Cgpa1
# 0           6.52     12
# 1           5.17     10
# 2           8.86     12
# 3           7.27     10
# 4           7.30     11
# ..           ...    ...
# 95          6.38     10
# 96          7.76     12
# 97          7.78     10
# 98          5.63     12
# 99          6.61     10
#
# [100 rows x 2 columns]

# %%
df1['half']=df1['cgpa'].where(df1['cgpa']>7,other=0)
df1.head(10)
# Out:
#    cgpa  resume_score  placed  Cgpa1  half
# 0    12          6.52       1     12    12
# 1    10          5.17       0     10    10
# 2    12          8.86       1     12    12
# 3    10          7.27       1     10    10
# 4    11          7.30       1     11    11
# 5    12          6.19       1     12    12
# 6     9          7.09       0      9     9
# 7    10          6.29       0     10    10
# 8    10          6.71       0     10    10
# 9    11          7.12       1     11    11

# %%
df1.sample(8)
df1
# Out:
#     cgpa  resume_score  placed  Cgpa1  half
# 0     12          6.52       1     12    12
# 1     10          5.17       0     10    10
# 2     12          8.86       1     12    12
# 3     10          7.27       1     10    10
# 4     11          7.30       1     11    11
# ..   ...           ...     ...    ...   ...
# 95    10          6.38       0     10    10
# 96    12          7.76       1     12    12
# 97    10          7.78       0     10    10
# 98    12          5.63       1     12    12
# 99    10          6.61       0     10    10
#
# [100 rows x 5 columns]

# %%
# DATA FRAME MERAGING : The merge() method updates the content of two DataFrame by merging them together, using the specified method(s).

# %%
data1 = {
  "name": ["Sally", "Mary", "John"],
  "age": [50, 40, 30]
}

data2 = {
  "name": ["Sally", "Peter", "Micky"],
  "age": [77, 44, 22]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

newdf = df1.merge(df2, how='right')

# %%
newdf
# Out:
#     name  age
# 0  Sally   77
# 1  Peter   44
# 2  Micky   22

# %%
# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}

# %%
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd

# %%
df2
# Out:
#      Name  Age    Address Qualification
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad          Bcom
# 3  Hitesh   52    Kannuaj        B.hons

# %%
new_dt = pd.concat([df1,df2])
new_dt
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad          Bcom
# 3  Hitesh   52    Kannuaj        B.hons

# %%
pd.concat([df1,df2],axis=1,join='inner')
# Out:
#      Name  Age    Address Qualification    Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc    Abhi   17     Nagpur         Btech
# 1  Princi   24     Kanpur            MA  Ayushi   14     Kanpur           B.A
# 2  Gaurav   22  Allahabad           MCA  Dhiraj   12  Allahabad          Bcom
# 3    Anuj   32    Kannuaj           Phd  Hitesh   52    Kannuaj        B.hons
