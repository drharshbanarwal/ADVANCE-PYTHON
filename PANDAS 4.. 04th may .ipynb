# %%
import pandas as pd

# %%
df1 = pd.read_csv('covid_toy - covid_toy.csv')
df1
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
g = df1.city.unique()
for city in g:
    df[city]=df['has_covid'].where((df['has_covid']=="Yes") & (df['city']==city),0)
df1.head(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'has_covid'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 3
#       1 g = df1.city.unique()
#       2 for city in g:
# ...

# %%
# PANDAS DAY 4 :

# %%
# EDA : EXPlORATERY DATA ANALYSIS :

# PARTS OF EDA :
# (1) UNIVARIATE ANALYSIS => ANALYSIS ON A SINGLE INDIPENDENT COLUMN.
# (2) BIVARIATE ANALYSIS => ANALYSIS ON TWO COLUMN.
# (3) MULTIVARIATE ANALYSIS => ANALYSIS ON MORE THAN 2 COLUMN.

# %%
# DATA TYPE :
# 1. Numerical data => Continous data => Age(YYears,month,days) hight,weight etc.
# 2. Catergorical data => Descrete Data => Total number of employees, material status, student result

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic - titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# univariate Analysis

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# If we want to see actual value then we use value_count().

df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
# changing the data into PIECHART . (if we want to find thw percentge) (we use piecahrt)
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# If we have numerical data then we use Histogram.
# Because it finds the distribution.

# %%
plt.hist(x=df['Age'])
plt.show()

# %%
# 3. BOXPLOT
# To find our outliers.

# 1. Lower Fence
# 2. 25% data
# 3. IQR (inter quartile range)(75%-25%)
# 4. 75% Data
# 5. Upper Fence

# %%
# x=1,2,3,4,5
# mean=(1+2+3+4+5)/5=15/5=3  ## here 100 is outlier.
# x=1,2,3,4,5,100
# mean= 15+100/6=115/6=19.3

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# BIVARIATE ANALYSIS

# %%
# 1 SCATTERPLOT (NUMERICAL COLUMN - NUMERICAL COLOUMN)

# %%
sns.scatterplot(x=tips['total_bill'],
                y=tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# finding multivariate
sns.scatterplot(x="total_bill",y="tip",data=tips,hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,hue=tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
